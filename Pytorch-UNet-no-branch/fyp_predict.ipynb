# %%
from evaluate import evaluate
from unet import UNet

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import torch
from PIL import Image

from torchvision import transforms

net = UNet(n_channels=3, n_classes=2, bilinear=False)

# %%
from torchsummary import summary
net.to(device='cpu')
summary(net, (3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-543ed6665127> in <module>
#       1 from torchsummary import summary
#       2 net.to(device='cpu')
# ----> 3 summary(net, (3, 224, 224))
#
# /opt/conda/lib/python3.6/site-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /raid/Data/videos/Pytorch-UNet-no-branch/unet/unet_model.py in forward(self, x)
#      24
#      25     def forward(self, x):
# ---> 26         x1 = self.inc(x)
#      27         x2 = self.down1(x1)
#      28         x3 = self.down2(x2)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /raid/Data/videos/Pytorch-UNet-no-branch/unet/unet_parts.py in forward(self, x)
#      23
#      24     def forward(self, x):
# ---> 25         return self.double_conv(x)
#      26
#      27
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     418                             _pair(0), self.dilation, self.groups)
#     419         return F.conv2d(input, weight, self.bias, self.stride,
# --> 420                         self.padding, self.dilation, self.groups)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same

# %%
net.load_state_dict(torch.load('checkpoints/checkpoint_epoch_224x224_11.pth'))
net.eval()
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (linear_1): Linear(in_features=1024, out_features=512, bias=True)
#   (linear_2): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
def preprocess(pil_img, scale, is_mask):
        w, h = pil_img.size
#         print(w,h)
        newW, newH = int(scale * w), int(scale * h)
        assert newW > 0 and newH > 0, 'Scale is too small, resized images would have no pixel'
        pil_img = pil_img.resize((newW, newH))
        img_ndarray = np.asarray(pil_img)


        if img_ndarray.ndim == 2 and not is_mask:
            img_ndarray = img_ndarray[np.newaxis, ...]
        elif not is_mask:
            img_ndarray = img_ndarray.transpose((2, 0, 1))

        if not is_mask:
            img_ndarray = img_ndarray / 255
            return img_ndarray

# %%
import json
import os
import random
file = open('../dfdc_deepfake_challenge/metadata.json')
file = json.load(file)

# %%
true = 0
false = 0
for file_name in os.listdir('../dfdc_deepfake_challenge/dataset_new_1/training/crops/'):
    filename = '../dfdc_deepfake_challenge/dataset_new_1/training/crops/'+file_name
    scale=1.0
    img = Image.open(filename).resize((224,224),Image.NEAREST)
    img = torch.from_numpy(preprocess(img, scale, is_mask=False))
    # img = torch.as_tensor(img.copy()).float().contiguous()?\
    img = img.unsqueeze(0)
    img = img.to(device='cpu', dtype=torch.float32)
    
    name = file_name.split('_')[0]
    
    if file[name+'.mp4']['label'] == 'REAL':
        true_out = 1.0
    else:
        true_out = 0.0
        
    pred = net(img)
    pred = torch.round(pred[0][0])
    pred = pred.detach().numpy()
    
#     print(true_out, pred)
    if pred == true_out:
        true+=1
    else:
        print(pred, true_out, file_name)
        false+=1
        
print('Correct {}, Wrong {}'.format(true, false))
# Out:
# 0.0 1.0 vnzfkjxkhr_3.png
# 1.0 0.0 umensyykfm_5.png
# 1.0 0.0 fzwnnccurn_4.png
# 1.0 0.0 onprahphaz_6.png
# 0.0 1.0 faslgdifiu_1.png
# 0.0 1.0 finxnswaul_5.png
# 1.0 0.0 rhcyvdfomq_1.png
# 1.0 0.0 myldaqelfu_4.png
# 0.0 1.0 uqrwgslayc_1.png
# 0.0 1.0 ffoccujyxz_3.png
# 0.0 1.0 xitvbsjxoe_5.png
# 0.0 1.0 iwhzhemnul_6.png
# 0.0 1.0 vqrsnqwezt_2.png
# 1.0 0.0 ndexnspbog_6.png
# 0.0 1.0 yofslrsdjt_3.png
# 0.0 1.0 vftavpyqby_2.png
# 0.0 1.0 ivexyynvqc_7.png
# 0.0 1.0 gawbagazjl_3.png
# 0.0 1.0 pdiozvcjlh_7.png
# 0.0 1.0 kqlxflempd_2.png
# 0.0 1.0 kvtdcfpsdc_7.png
# 1.0 0.0 ymzihxvcsy_1.png
# 0.0 1.0 fzdpzjenfq_6.png
# 1.0 0.0 ghhkuajlex_5.png
# 1.0 0.0 nqkboitiaz_1.png
# 0.0 1.0 xoiyevqols_3.png
# 0.0 1.0 nrzxgzsvyt_6.png
# 1.0 0.0 gtolbxsyzd_7.png
# 0.0 1.0 nvkzpexyzg_5.png
# 1.0 0.0 zgcwolwyol_1.png
# 1.0 0.0 boffgepsfl_2.png
# 0.0 1.0 vyuvcsjiwn_6.png
# 1.0 0.0 lvkuovvday_7.png
# 0.0 1.0 vumapsooel_6.png
# 1.0 0.0 iqrqhrixfp_3.png
# 0.0 1.0 owvxxmuceg_2.png
# 0.0 1.0 rrytrtjloc_6.png
# 0.0 1.0 rgeaimngac_5.png
# 0.0 1.0 ftxkyhpuyp_5.png
# 1.0 0.0 obrbjarzaz_3.png
# 1.0 0.0 ejymqfawpz_4.png
# 1.0 0.0 wrliclxsom_5.png
# 0.0 1.0 ykgfznxxut_1.png
# 0.0 1.0 aycjerwghk_6.png
# 0.0 1.0 tjtxivvbcq_5.png
# 1.0 0.0 gqofkxplaa_3.png
# 1.0 0.0 gvejaseods_3.png
# 0.0 1.0 ceuicumdmo_5.png
# 0.0 1.0 qkpjmnzppr_7.png
# 0.0 1.0 pgybuuxxip_3.png
# 1.0 0.0 ojdrqflslr_6.png
# 0.0 1.0 umukykyqpv_1.png
# 0.0 1.0 zmdzmbfneh_2.png
# 1.0 0.0 pydicxfaui_7.png
# 1.0 0.0 ijkwihnmld_4.png
# 0.0 1.0 sttnfyptum_1.png
# 1.0 0.0 qkrumcvepk_2.png
# 0.0 1.0 juspfcwdxi_5.png
# 1.0 0.0 qegnidgfdh_6.png
# 1.0 0.0 ndjerymuzq_3.png
# 1.0 0.0 olgbljtutz_1.png
# 0.0 1.0 ecbdlzgwnb_4.png
# 0.0 1.0 tlaxtosyoi_7.png
# 0.0 1.0 wpdrxrheoy_5.png
# 1.0 0.0 cmpzwzrfsp_1.png
# 0.0 1.0 miiaudwrsp_6.png
# 1.0 0.0 fuuvolwkvh_6.png
# 0.0 1.0 oimivjeigb_4.png
# 1.0 0.0 smmommoglu_5.png
# 1.0 0.0 oaqdxmjrmc_7.png
# 1.0 0.0 lupwespgml_5.png
# 0.0 1.0 viukiigwtc_4.png
# 1.0 0.0 htaszoajhi_7.png
# 1.0 0.0 ddgdbctyif_6.png
# 0.0 1.0 azyluukyhz_7.png
# 1.0 0.0 zbpncrxqfu_2.png
# 0.0 1.0 nweufafotd_2.png
# 0.0 1.0 rfrulefxdj_4.png
# 1.0 0.0 lgwkjdthox_5.png
# 0.0 1.0 ruenzqaiww_7.png
# 1.0 0.0 ovrpqqqply_3.png
# 0.0 1.0 oimivjeigb_3.png
# 0.0 1.0 dkuayagnmc_5.png
# 0.0 1.0 viylujrvtf_2.png
# 1.0 0.0 yltojzqtuc_3.png
# 0.0 1.0 izjbunivhp_7.png
# 0.0 1.0 bsjezfsydc_3.png
# 1.0 0.0 fuixycdfqu_4.png
# 1.0 0.0 gqlpwihuku_1.png
# 0.0 1.0 elsvnmrlue_4.png
# 1.0 0.0 rfmusgukat_6.png
# 1.0 0.0 onhthjbayk_7.png
# 0.0 1.0 itnumzdchb_2.png
# 0.0 1.0 yqovednfti_2.png
# 0.0 1.0 ypasdmkmuv_1.png
# 0.0 1.0 vdkacknwck_1.png
# 0.0 1.0 fxpjhpdfzd_2.png
# 0.0 1.0 urfuhntprf_4.png
# 1.0 0.0 dpzayxcsok_5.png
# 0.0 1.0 fhsckyuezm_4.png
# 1.0 0.0 cctrhqvein_4.png
# 1.0 0.0 ozeczmmafh_6.png
# 1.0 0.0 kqcjqltrql_1.png
# 1.0 0.0 twmmodfrea_5.png
# 1.0 0.0 igwxjnfnos_5.png
# 0.0 1.0 rlmzkecohf_4.png
# 1.0 0.0 sunzloiilo_5.png
# 1.0 0.0 wcovfnrnev_5.png
# 1.0 0.0 qtdxrbazya_4.png
# 1.0 0.0 murpsmxdii_4.png
# 1.0 0.0 nfvqnqwzdx_5.png
# 1.0 0.0 ujmtqszexn_5.png
# 1.0 0.0 zsormhyuwd_4.png
# 1.0 0.0 leyrbovjjq_6.png
# 0.0 1.0 bpwynspgkx_3.png
# 1.0 0.0 isbmgabjat_2.png
# 1.0 0.0 tbqxswvzxl_3.png
# 1.0 0.0 pmncasrtkf_3.png
# 0.0 1.0 vajhspvilv_2.png
# 1.0 0.0 gllcwjrhch_3.png
# 1.0 0.0 xmwxfctxcr_4.png
# 0.0 1.0 thngpalfbb_5.png
# 0.0 1.0 ppghcvwxhb_4.png
# 1.0 0.0 hzidewmuub_1.png
# 0.0 1.0 exconiqian_4.png
# 0.0 1.0 uvmnbnminv_6.png
# 0.0 1.0 bkahsatkrs_2.png
# 0.0 1.0 liureznisp_6.png
# 1.0 0.0 yikahgeuey_1.png
# 0.0 1.0 rmwvicexuo_5.png
# 1.0 0.0 vnoirmbehi_2.png
# 0.0 1.0 nuhvodokrm_6.png
# 1.0 0.0 wdycpqchcn_2.png
# 0.0 1.0 ttujtsurby_5.png
# 0.0 1.0 engsjjoxfe_3.png
# 0.0 1.0 sfsyqyeqcc_1.png
# 1.0 0.0 ipprkorglm_3.png
# 1.0 0.0 wwbqrjjmwg_4.png
# 1.0 0.0 eqszovemao_2.png
# 0.0 1.0 ekwidzkjjg_4.png
# 1.0 0.0 addewzbsic_6.png
# 1.0 0.0 eqxmeoystj_5.png
# 1.0 0.0 bdrvwexsfj_3.png
# 1.0 0.0 zrtzordyjm_4.png
# 1.0 0.0 lvriciaexj_3.png
# 0.0 1.0 sgsrjchbsh_3.png
# 0.0 1.0 jiivsvouxw_2.png
# 1.0 0.0 glviwluzaj_2.png
# 0.0 1.0 jpquwcujcd_1.png
# 1.0 0.0 xhyjcncbcl_7.png
# 0.0 1.0 yflzmdpkab_5.png
# 1.0 0.0 hmqjhkqkte_3.png
# 0.0 1.0 acuhmmgmtx_2.png
# 1.0 0.0 ssoutkswgl_3.png
# 1.0 0.0 dbolphrfma_6.png
# 1.0 0.0 ddtuholdfz_1.png
# 0.0 1.0 fhrsqtuohm_7.png
# 0.0 1.0 ufqeokijvk_7.png
# 1.0 0.0 axntzvpfmh_2.png
# 1.0 0.0 ungikzaugs_7.png
# 1.0 0.0 tnfuystqkg_7.png
# 1.0 0.0 vnpzvqphkm_1.png
# 1.0 0.0 mveoqfdzcs_5.png
# 0.0 1.0 keikgjgled_1.png
# 0.0 1.0 pvsslamopo_6.png
# 1.0 0.0 qkqkbebvgq_2.png
# 1.0 0.0 tcyzcunttw_3.png
# 0.0 1.0 rbcvbrppdu_6.png
# 0.0 1.0 syhzdgxcne_4.png
# 1.0 0.0 koduncziii_3.png
# 0.0 1.0 spzmqugvtn_5.png
# 0.0 1.0 elefkzmxey_4.png
# 0.0 1.0 acefbeffbr_4.png
# 0.0 1.0 fygxczhbsf_7.png
# 1.0 0.0 jbwzrlpevt_6.png
# 1.0 0.0 vlluwerdrf_1.png
# 1.0 0.0 pxnjwmafbx_2.png
# 1.0 0.0 tbaxhxvgsq_2.png
# 0.0 1.0 cvoxjflaxg_3.png
# 1.0 0.0 mqnddeyzlm_1.png
# 1.0 0.0 miuaiytuus_7.png
# 0.0 1.0 lydemyfffs_2.png
# 0.0 1.0 fsxdzxyhqh_3.png
# 0.0 1.0 tybjnixgub_6.png
# 0.0 1.0 fxqbtvmyaw_3.png
# 0.0 1.0 bglsrppmtk_1.png
# 1.0 0.0 uwazrtsbpk_6.png
# 1.0 0.0 fgwujwtmcx_7.png
# 1.0 0.0 tqrjmasczr_3.png
# 0.0 1.0 dcfodaqazt_2.png
# 1.0 0.0 uggnfmqfka_5.png
# 1.0 0.0 pmwmuvzomj_1.png
# 0.0 1.0 eezednepcp_1.png
# 0.0 1.0 bgtvsmksqq_5.png
# 1.0 0.0 umvqagqmpt_5.png
# 0.0 1.0 mxstnbsyll_7.png
# 1.0 0.0 xccbaancfj_2.png
# 0.0 1.0 pvrncpaovg_3.png
# 1.0 0.0 ggrxvrbnyo_5.png
# 0.0 1.0 evnbpdndlu_4.png
# 1.0 0.0 fvaphxsbiz_3.png
# 1.0 0.0 udpmccmnpt_3.png
# 0.0 1.0 ocsnhldayx_3.png
# 0.0 1.0 dzoespidyr_6.png
# 1.0 0.0 hajkizpxpz_4.png
# 0.0 1.0 wesnaptbrn_4.png
# 0.0 1.0 pgybuuxxip_1.png
# 1.0 0.0 rlxlgeaiqo_2.png
# 1.0 0.0 sfyyzmwjvt_2.png
# 0.0 1.0 advzryyfkn_5.png
# 1.0 0.0 oryetmnmtg_7.png
# 1.0 0.0 juoyxhclkj_3.png
# 0.0 1.0 ftxkyhpuyp_7.png
# 1.0 0.0 mtqwmnjqgo_1.png
# 1.0 0.0 ouxlzbudmi_7.png
# 0.0 1.0 wcqvzujamg_5.png
# 1.0 0.0 czygnxlbjc_5.png
# 0.0 1.0 jpquwcujcd_2.png
# 0.0 1.0 kiyvsruaai_1.png
# 0.0 1.0 tuhacvtkxk_3.png
# 0.0 1.0 drywmgvslp_3.png
# 0.0 1.0 kpkbtvsxlz_5.png
# 0.0 1.0 ezaaqjpswx_7.png
# 0.0 1.0 mwuywloapn_4.png
# 1.0 0.0 mtzvnmxgqj_2.png
# 1.0 0.0 bmgsqeuaqf_1.png
# 0.0 1.0 jqiayxomia_2.png
# 0.0 1.0 xrdopedqcu_4.png
# 0.0 1.0 kfgcbjjklh_5.png
# 0.0 1.0 whkrlhuqyg_6.png
# 0.0 1.0 wpdrxrheoy_1.png
# 1.0 0.0 ihexuaymou_7.png
# 1.0 0.0 wvkkqapkjv_1.png
# 0.0 1.0 jeunztbgqk_3.png
# 1.0 0.0 syaludhwxe_4.png
# 1.0 0.0 vbputtjekp_4.png
# 0.0 1.0 fqkhinwwqy_1.png
# 0.0 1.0 misusdkemd_3.png
# 0.0 1.0 kdxjncawfy_7.png
# 0.0 1.0 mkwhpzswmo_6.png
# 0.0 1.0 qtnqqgllmx_6.png
# 1.0 0.0 oliigwfyvt_4.png
# 0.0 1.0 kvklczjukh_2.png
# 1.0 0.0 rgredpxmpo_5.png
# 0.0 1.0 enyfzkpdeq_5.png
# 0.0 1.0 cpipsblwsv_6.png
# 0.0 1.0 yxaqsflxnf_2.png
# 1.0 0.0 ddlutqlzwv_5.png
# 0.0 1.0 ubydbjxdmr_1.png
# 0.0 1.0 bcbrujsqxo_3.png
# 0.0 1.0 eubuplmxrk_7.png
# 1.0 0.0 sewqiqzfki_6.png
# 1.0 0.0 yojgjueqta_4.png
# 1.0 0.0 ejpywzaser_2.png
# 1.0 0.0 lrquoplrdy_4.png
# 0.0 1.0 bzaqomdlim_3.png
# 1.0 0.0 tdgglfmpsm_7.png
# 1.0 0.0 yehnjsxyzc_1.png
# 1.0 0.0 ubzwpartrm_5.png
# 1.0 0.0 wgusxqhklm_7.png
# 1.0 0.0 nnwyjeeoiw_2.png
# 0.0 1.0 qlfdwthkwy_3.png
# 1.0 0.0 aorhjnequr_5.png
# 1.0 0.0 gfzleovdnl_6.png
# 0.0 1.0 qhzszqjbky_1.png
# 1.0 0.0 bgpwqfqnbi_4.png
# 1.0 0.0 wrorqvpbsi_7.png
# 0.0 1.0 gxdauznilj_3.png
# 0.0 1.0 kucoqzfsnh_7.png
# 0.0 1.0 qkkubsdlzn_3.png
# 1.0 0.0 zbchoijdka_1.png
# 0.0 1.0 ouslpwefgh_7.png
# 1.0 0.0 ahbjzjoucp_1.png
# 1.0 0.0 tjtmlczbqy_3.png
# 0.0 1.0 mgssylcwny_3.png
# 0.0 1.0 amflyomuqj_5.png
# 1.0 0.0 ztpzbvukvp_3.png
# 1.0 0.0 weorueggqi_6.png
# 1.0 0.0 jqduafrenc_5.png
# 0.0 1.0 pldiwcmrdp_4.png
# 0.0 1.0 lkpotrabfp_1.png
# 1.0 0.0 ucljktpwrh_5.png
# 0.0 1.0 tzvimvnydj_6.png
# 0.0 1.0 pihdxqxmla_5.png
# 1.0 0.0 kttgpjwhqb_7.png
# 0.0 1.0 tvdzwxjcnb_4.png
# 1.0 0.0 wtgdnkeogm_4.png
# 1.0 0.0 uqnhilzzey_1.png
# 1.0 0.0 mgjwxjopnd_4.png
# 1.0 0.0 qqjjlfichi_4.png
# 1.0 0.0 ouhuqktnna_5.png
# 0.0 1.0 fduqklszee_5.png
# 0.0 1.0 gnykansqlk_7.png
# 0.0 1.0 fagrxzclau_2.png
# 0.0 1.0 pullzicjlk_6.png
# 0.0 1.0 fhrsqtuohm_2.png
# 0.0 1.0 mwoeriylvo_4.png
# 1.0 0.0 iqrqhrixfp_4.png
# 0.0 1.0 wgqlhxpvro_4.png
# 1.0 0.0 osrpepdagi_1.png
# 0.0 1.0 kmswpobxgf_2.png
# 0.0 1.0 kwxgiifbqt_3.png
# 0.0 1.0 zdhrhqmorn_7.png
# 0.0 1.0 tavsxtaoup_1.png
# 1.0 0.0 mlozmrhbee_4.png
# 0.0 1.0 jmaylyisgz_4.png
# 0.0 1.0 pxrhjlzird_5.png
# 1.0 0.0 ekensuxkkt_3.png
# 1.0 0.0 vtaagrckne_1.png
# 0.0 1.0 bstqzsknhe_6.png
# 1.0 0.0 rfuhnmpclz_7.png
# 0.0 1.0 kyfwctavtq_5.png
# 1.0 0.0 npjwiaxcjd_6.png
# 0.0 1.0 buquceghsg_3.png
# 0.0 1.0 nyfcbktuoy_3.png
# 0.0 1.0 ybjrqnqnno_3.png
# 1.0 0.0 iokiuqvept_5.png
# 1.0 0.0 woqggmgnbw_5.png
# 1.0 0.0 nkcswhzmac_5.png
# 0.0 1.0 oxokstotfw_5.png
# 0.0 1.0 azxmphhunl_3.png
# 1.0 0.0 vgehtbkfpe_6.png
# 0.0 1.0 ayntzgwakd_5.png
# 0.0 1.0 svkgvesvdy_2.png
# 0.0 1.0 elsvnmrlue_1.png
# 0.0 1.0 ssumpmrbdi_7.png
# 0.0 1.0 iwkdyefcry_6.png
# 1.0 0.0 mbkhjuleuv_4.png
# 1.0 0.0 urfnmqjzcm_5.png
# 1.0 0.0 mlxltyplsa_7.png
# 1.0 0.0 ziffnybneu_5.png
# 0.0 1.0 udibpixgcr_3.png
# 0.0 1.0 iksxzpqxzi_2.png
# 1.0 0.0 ejykbxakod_1.png
# 1.0 0.0 eqmxbrgkdd_1.png
# 0.0 1.0 ueeunxfric_4.png
# 0.0 1.0 auqgkzaacb_5.png
# 0.0 1.0 wqsveixiyo_4.png
# 0.0 1.0 hxzhvrhlfs_6.png
# 1.0 0.0 kjbfoacgzi_7.png
# 1.0 0.0 malzaqmoko_7.png
# 0.0 1.0 zsgtmhucct_5.png
# 1.0 0.0 bjqqudbued_2.png
# 0.0 1.0 wyxgpiibua_7.png
# 0.0 1.0 zukzbtpjkc_3.png
# 0.0 1.0 ohptxpsivl_3.png
# 0.0 1.0 gbwbyxszjl_5.png
# 1.0 0.0 degghmtwuw_3.png
# 1.0 0.0 bwbzczjett_6.png
# 1.0 0.0 kahoiruzzj_5.png
# 0.0 1.0 uwmejkcemy_4.png
# 0.0 1.0 aretvijthh_1.png
# 0.0 1.0 bxmlvyjhkm_5.png
# 0.0 1.0 azefstphot_3.png
# 0.0 1.0 oiozwvrdry_5.png
# 0.0 1.0 fsdeegievg_1.png
# 1.0 0.0 ksfkyiyrif_6.png
# 0.0 1.0 htqhzfwsmb_6.png
# 1.0 0.0 jalbvevoxn_3.png
# 0.0 1.0 lrqhmruflh_4.png
# 0.0 1.0 rmwvicexuo_3.png
# 1.0 0.0 ghhkuajlex_1.png
# 1.0 0.0 gqaybjiybn_5.png
# 0.0 1.0 yaivbfubpr_4.png
# 0.0 1.0 lnpakizjpy_7.png
# 1.0 0.0 bbagpnnxnv_1.png
# 1.0 0.0 xfzctfcitq_3.png
# 1.0 0.0 glfjllgfcg_7.png
# 0.0 1.0 fortjanwmb_1.png
# 0.0 1.0 zmdzmbfneh_4.png
# 1.0 0.0 arfqjhbpax_3.png
# 0.0 1.0 varyqeuood_3.png
# 1.0 0.0 qarwqwtpbl_2.png
# 1.0 0.0 vxxajypjxx_4.png
# 1.0 0.0 bsprlfyyyc_3.png
# 1.0 0.0 egkzkygmol_7.png
# 1.0 0.0 lqfjiqlokh_4.png
# 1.0 0.0 jqkzvipdcr_7.png
# 0.0 1.0 phxwzvjuep_7.png
# 1.0 0.0 jecphujqqk_7.png
# 0.0 1.0 fpmarcqjfr_1.png
# 1.0 0.0 snqogorujs_7.png
# 1.0 0.0 onyngdxyen_6.png
# 1.0 0.0 wntshsaoyt_5.png
# 0.0 1.0 cthyolvdif_7.png
# 0.0 1.0 dwxbothlyp_1.png
# 1.0 0.0 rieqbjzzxs_1.png
# 1.0 0.0 wvpnravyge_4.png
# 0.0 1.0 foeqdpisxf_6.png
# 1.0 0.0 nzbnqvtljv_1.png
# 1.0 0.0 ocggvgyisf_1.png
# 0.0 1.0 eacjsuqenz_2.png
# 1.0 0.0 kkcmpozyjb_4.png
# 1.0 0.0 vpcwwzaxmn_1.png
# 1.0 0.0 xcvmyhgfxw_6.png
# 1.0 0.0 wbqdwrulkm_5.png
# 0.0 1.0 jhyrglgwqj_7.png
# 1.0 0.0 dazseswwpp_7.png
# 0.0 1.0 rraluxdmqu_5.png
# 0.0 1.0 whneslhtcb_7.png
# 0.0 1.0 htgyfaawpd_5.png
# 1.0 0.0 rodgsmgued_7.png
# 0.0 1.0 tshtheczgj_6.png
# 0.0 1.0 tcxgercomn_4.png
# 0.0 1.0 pzymesrkiw_2.png
# 1.0 0.0 nmhgmueqie_2.png
# 0.0 1.0 fkyrrigzpt_5.png
# 0.0 1.0 xpatyuhvaq_2.png
# 0.0 1.0 mlsrcayqar_7.png
# 0.0 1.0 uzdmlxunsd_4.png
# 1.0 0.0 jkusgrhdfy_4.png
# 0.0 1.0 crxnkfunvm_6.png
# 1.0 0.0 ihihvlytpy_4.png
# 0.0 1.0 ijnrqgiwvr_4.png
# 0.0 1.0 sjipeifdrn_7.png
# 0.0 1.0 qmifyvokds_3.png
# 0.0 1.0 aayrffkzxn_6.png
# 1.0 0.0 xzwxocqkez_4.png
# 1.0 0.0 tcizhqxeak_5.png
# 1.0 0.0 fakxwnyyql_5.png
# 1.0 0.0 cdvlkckrxw_2.png
# 1.0 0.0 rcjcofptsj_5.png
# 0.0 1.0 vbvcmubccp_7.png
# 1.0 0.0 njacfyjxfg_6.png
# 0.0 1.0 pxrhjlzird_4.png
# 0.0 1.0 qrbpkxbaeh_3.png
# 0.0 1.0 sfbzqkseyn_6.png
# 1.0 0.0 pgqcghptso_4.png
# 1.0 0.0 ofzztoeoyu_3.png
# 1.0 0.0 aosonazrhc_7.png
# 0.0 1.0 ijulzuuplt_6.png
# 1.0 0.0 dvruoqbxnd_1.png
# 0.0 1.0 aaapwqhxli_7.png
# 1.0 0.0 qhqduqavkh_2.png
# 1.0 0.0 iasxagvyyu_1.png
# 1.0 0.0 mbcmbmicce_1.png
# 1.0 0.0 yhxgxxfcth_7.png
# 1.0 0.0 kgeeivvuhe_6.png
# 0.0 1.0 iezlgezozt_3.png
# 0.0 1.0 vuvakikxia_3.png
# 1.0 0.0 txtwccefim_2.png
# 1.0 0.0 sjjdkyumzi_3.png
# 1.0 0.0 vfhfduegkh_4.png
# 1.0 0.0 qzyhlwwpyi_4.png
# 1.0 0.0 rikuzqxsyb_2.png
# 1.0 0.0 defeyoyaik_6.png
# 0.0 1.0 oimivjeigb_1.png
# 1.0 0.0 nujpgxavmm_3.png
# 1.0 0.0 kbdfvpatrl_1.png
# 1.0 0.0 sttjzwvvnu_3.png
# 0.0 1.0 nweufafotd_7.png
# 0.0 1.0 nznptkguft_3.png
# 1.0 0.0 hflzbzsfjq_5.png
# 0.0 1.0 hmfcptrods_6.png
# 1.0 0.0 qvfdryghjx_2.png
# 1.0 0.0 xbhjfflwzv_1.png
# 0.0 1.0 bxmlvyjhkm_1.png
# 1.0 0.0 zypkaxiras_3.png
# 0.0 1.0 ijkkhohiym_1.png
# 0.0 1.0 wjsftxrqzj_7.png
# 0.0 1.0 jioqrlrmxl_5.png
# 1.0 0.0 yfkmhjjrig_4.png
# 0.0 1.0 hpeyakpjiu_2.png
# 1.0 0.0 maxybxfgts_5.png
# 0.0 1.0 hbcasaspdr_4.png
# 1.0 0.0 rsghvfqkhz_7.png
# 1.0 0.0 bhzyjsztok_3.png
# 1.0 0.0 svynysfmaq_3.png
# 1.0 0.0 jejocgtpyx_2.png
# 0.0 1.0 yhwewmfucb_5.png
# 0.0 1.0 fpgmlnpyys_1.png
# 1.0 0.0 ipakfzcdvv_6.png
# 1.0 0.0 ucnehbdydg_2.png
# 1.0 0.0 qpqozdlxgv_2.png
# 0.0 1.0 sqmocpagkn_7.png
# 1.0 0.0 xnqmkqdnct_7.png
# 0.0 1.0 nwiwdmkkwn_7.png
# 1.0 0.0 zhwtvlawvg_1.png
# 1.0 0.0 dyrpdgfucs_2.png
# 0.0 1.0 bnfxegkque_4.png
# 0.0 1.0 xexqjemxyq_4.png
# 0.0 1.0 oqgeqvxukk_5.png
# 0.0 1.0 vftavpyqby_1.png
# 1.0 0.0 cokftyhjmk_1.png
# 0.0 1.0 ykpatcwgia_7.png
# 0.0 1.0 wvpxqmpjya_1.png
# 1.0 0.0 fgoriveyxg_2.png
# 0.0 1.0 wapebjxejr_6.png
# 0.0 1.0 atkqtbbbeq_2.png
# 0.0 1.0 yewabcvapc_5.png
# 1.0 0.0 ledwcahvbf_4.png
# 0.0 1.0 mllqfiowhs_3.png
# 0.0 1.0 hxzhvrhlfs_4.png
# 0.0 1.0 vwmcoxzqkq_3.png
# 0.0 1.0 wowqljawhw_7.png
# 1.0 0.0 hstdygmlas_3.png
# 0.0 1.0 owgefmanby_7.png
# 1.0 0.0 bjhieizrjq_3.png
# 1.0 0.0 ipuniglqkv_4.png
# 0.0 1.0 wozjdjdpse_4.png
# 0.0 1.0 hffqkokckx_7.png
# 0.0 1.0 hinogxnrhx_2.png
# 0.0 1.0 zukzbtpjkc_6.png
# 0.0 1.0 qwpypedkpr_1.png
# 0.0 1.0 tymcuyunhe_2.png
# 0.0 1.0 bteafrnibw_7.png
# 0.0 1.0 chmpderfqz_5.png
# 1.0 0.0 wckkpkpzij_3.png
# 1.0 0.0 cayliwbhpq_4.png
# 0.0 1.0 vqnocyqksq_4.png
# 1.0 0.0 tssvjchlwe_4.png
# 1.0 0.0 mohimgison_5.png
# 1.0 0.0 iafxqimtct_7.png
# 0.0 1.0 nwfhiittig_4.png
# 1.0 0.0 opavejjqtl_1.png
# 1.0 0.0 wksybmxekv_2.png
# 0.0 1.0 sfzbjyskjx_7.png
# 1.0 0.0 wyzqsjyxqu_6.png
# 0.0 1.0 azcbnczesb_2.png
# 0.0 1.0 gqlajpyklv_3.png
# 0.0 1.0 jegaokdbdb_5.png
# 0.0 1.0 vdmaeysfhq_3.png
# 1.0 0.0 rejmrurgnf_1.png
# 0.0 1.0 qnxqnoausv_3.png
# 0.0 1.0 wpdrxrheoy_6.png
# 0.0 1.0 oyhiaxpwfa_6.png
# 0.0 1.0 cvtwlzgzne_5.png
# 1.0 0.0 hgbosjbwer_1.png
# 1.0 0.0 lsuhmstevj_6.png
# 0.0 1.0 pqjjvrkkrv_1.png
# 1.0 0.0 gdskjdylwz_3.png
# 1.0 0.0 hrzmpehsmo_6.png
# 0.0 1.0 eztwadaxde_5.png
# 0.0 1.0 mdtgousjad_1.png
# 1.0 0.0 ltdrdqwsas_5.png
# 1.0 0.0 tbqynhntxo_6.png
# 1.0 0.0 ncwyatzoff_4.png
# 0.0 1.0 fezttluhlf_7.png
# 1.0 0.0 fobxxpujgt_4.png
# 0.0 1.0 nhikvdyyyg_1.png
# 0.0 1.0 bjhqszctit_1.png
# 0.0 1.0 qxmvgpsbpg_2.png
# 0.0 1.0 hpyhoykdwo_2.png
# 0.0 1.0 rctronqqjs_5.png
# 0.0 1.0 rlvgtsjyer_2.png
# 1.0 0.0 saffgjgwzy_5.png
# 0.0 1.0 egfspresvk_4.png
# 0.0 1.0 przmougwsm_3.png
# 1.0 0.0 qbjjkwellp_3.png
# 1.0 0.0 gojtqqxkca_1.png
# 1.0 0.0 pxowmfjlhp_5.png
# 1.0 0.0 ekkdjkirzq_4.png
# 1.0 0.0 gblclehusp_1.png
# 1.0 0.0 orxcjhvtht_2.png
# 1.0 0.0 nirxtmboor_5.png
# 0.0 1.0 jatpyqmdhn_7.png
# 0.0 1.0 crezycjqyk_1.png
# 1.0 0.0 ndhytzvnzs_3.png
# 0.0 1.0 ixplzwjivh_4.png
# 1.0 0.0 idrfcnqkmy_5.png
# 0.0 1.0 sysdotnfua_5.png
# 1.0 0.0 ktsowyvltg_4.png
# 1.0 0.0 qdjdzkhnnk_4.png
# 0.0 1.0 zmdkxnjejh_2.png
# 1.0 0.0 qvwzyydjtt_6.png
# 0.0 1.0 xjfmirjqdf_5.png
# 0.0 1.0 kviymjchga_3.png
# 0.0 1.0 fhhpgvcqoh_7.png
# 1.0 0.0 wbvlgevkmb_7.png
# 0.0 1.0 blsubpozyk_6.png
# 1.0 0.0 xbzswkjvyx_2.png
# 0.0 1.0 efmtxmmbfk_1.png
# 0.0 1.0 sfsyqyeqcc_6.png
# 1.0 0.0 owccsycepe_4.png
# 0.0 1.0 yuzdamakoa_3.png
# 0.0 1.0 jhecetyfym_5.png
# 1.0 0.0 dlwmbadytf_4.png
# 0.0 1.0 fraqjvnoxk_3.png
# 1.0 0.0 zjrdqaomkh_4.png
# 1.0 0.0 exjnpsilrw_2.png
# 1.0 0.0 uuqkvuejdf_1.png
# 0.0 1.0 dcfodaqazt_5.png
# 0.0 1.0 xitvbsjxoe_6.png
# 1.0 0.0 miyzalzegh_6.png
# 0.0 1.0 dzoespidyr_7.png
# 1.0 0.0 rtahwegkfs_4.png
# 0.0 1.0 vxvghzwwzk_7.png
# 0.0 1.0 hjrkzsbpvt_5.png
# 1.0 0.0 qfzmoiywft_6.png
# 1.0 0.0 wdgkxihibu_7.png
# 1.0 0.0 dtwbmdgqsl_5.png
# 1.0 0.0 mxnbqfecsc_5.png
# 0.0 1.0 wtmhkoctjf_6.png
# 1.0 0.0 vxtbxyegcj_6.png
# 1.0 0.0 zmgffszavc_5.png
# 0.0 1.0 etlroolqer_6.png
# 1.0 0.0 fcjgetycim_1.png
# 1.0 0.0 yblxtrlhpn_5.png
# 1.0 0.0 hltxqhuaru_4.png
# 1.0 0.0 lyhqnuoycr_5.png
# 0.0 1.0 nebsjsaqie_5.png
# 1.0 0.0 gvugievkqg_4.png
# 1.0 0.0 svczsyaksm_5.png
# 1.0 0.0 uqohwjybkg_2.png
# 0.0 1.0 ecrtyidcrf_2.png
# 1.0 0.0 jttbenjinn_3.png
# 0.0 1.0 jqrfrqykue_2.png
# 1.0 0.0 gobvnzkjaf_7.png
# 0.0 1.0 xrugmaiubc_5.png
# 1.0 0.0 niawhrtfjv_2.png
# 1.0 0.0 dzlrdixjgv_5.png
# 1.0 0.0 gdnnieahty_4.png
# 1.0 0.0 qqplrvxzjq_2.png
# 0.0 1.0 khaeuyycza_2.png
# 1.0 0.0 xjpmceyryy_3.png
# 0.0 1.0 wibskravnb_3.png
# 0.0 1.0 ewpofkrxae_3.png
# 0.0 1.0 ibgrtmlmjk_5.png
# 0.0 1.0 tjnlcylcoe_3.png
# 1.0 0.0 kvbicaaqot_2.png
# 0.0 1.0 qslerxmbjt_3.png
# 1.0 0.0 dfpizimddw_2.png
# 0.0 1.0 xcviojioko_3.png
# 0.0 1.0 vxvghzwwzk_2.png
# 1.0 0.0 jcafibbcdx_6.png
# 0.0 1.0 bqtnaozkjr_6.png
# 0.0 1.0 frwpjswdnr_1.png
# 1.0 0.0 kyzyltiodn_6.png
# 1.0 0.0 ppyoleobwp_5.png
# 1.0 0.0 czboylujng_4.png
# 0.0 1.0 qbwmzlyqkk_7.png
# 0.0 1.0 qokxxuayqn_2.png
# 1.0 0.0 okxgxnrnbh_5.png
# 1.0 0.0 hivywjxnjz_2.png
# 0.0 1.0 qebvcnhbej_1.png
# 1.0 0.0 tgeoqtnjsp_5.png
# 0.0 1.0 dhgvvblxsu_6.png
# 0.0 1.0 ypaxbuazvj_1.png
# 1.0 0.0 eqxvuwzyke_2.png
# 0.0 1.0 zoaavzmtre_2.png
# 1.0 0.0 dmspqijafg_7.png
# 1.0 0.0 qwqsyeppwg_7.png
# 1.0 0.0 qlhqgnuehw_6.png
# 1.0 0.0 miezsztvjn_3.png
# 0.0 1.0 ukiheldhqs_6.png
# 0.0 1.0 uojgiwhlfg_5.png
# 1.0 0.0 wrkplbjpat_5.png
# 0.0 1.0 csmezlywcs_2.png
# 1.0 0.0 exanjjxzre_2.png
# 0.0 1.0 oezufleysu_6.png
# 0.0 1.0 sheunnhdxe_7.png
# 0.0 1.0 yypbrzvfpa_4.png
# 1.0 0.0 jnuptiqqbe_1.png
# 1.0 0.0 jyseigrfah_3.png
# 1.0 0.0 pdasccqjoa_5.png
# 0.0 1.0 wcaaxxzzti_7.png
# 1.0 0.0 msqhpibjls_3.png
# 0.0 1.0 jqfnkkjjea_6.png
# 1.0 0.0 vhiixsmvyc_7.png
# 0.0 1.0 zgsbhofcsw_7.png
# 0.0 1.0 uvdzymytyr_7.png
# 0.0 1.0 tkkdojaodp_1.png
# 0.0 1.0 ndpdopglxk_1.png
# 0.0 1.0 qazoxlmqwq_5.png
# 0.0 1.0 rnxzqumvvl_6.png
# 0.0 1.0 qjnrsisslk_1.png
# 0.0 1.0 lmegljdeop_4.png
# 1.0 0.0 bgmsbthrmj_6.png
# 1.0 0.0 xgqioqcgxa_7.png
# 1.0 0.0 oqgjufqaeg_2.png
# 1.0 0.0 kcxanahahl_4.png
# 0.0 1.0 xbentgemej_1.png
# 1.0 0.0 vwprneelzg_7.png
# 0.0 1.0 hffqkokckx_3.png
# 0.0 1.0 ibebxwclro_5.png
# 0.0 1.0 oqgeqvxukk_3.png
# 1.0 0.0 sbhnywxsfg_1.png
# 1.0 0.0 foggejxjea_4.png
# 1.0 0.0 ndldhhfxyu_7.png
# 0.0 1.0 qarqtkvgby_6.png
# 1.0 0.0 erbnvtidau_1.png
# 1.0 0.0 ihpscljcdw_2.png
# 1.0 0.0 wupqwhzzuz_3.png
# 0.0 1.0 pdgzsvxvht_6.png
# 0.0 1.0 jtmsdyckqs_1.png
# 1.0 0.0 gwokxqgiyr_2.png
# 0.0 1.0 yflzmdpkab_2.png
# 1.0 0.0 pnuaczdxdj_2.png
# 0.0 1.0 wmjahdrbyr_1.png
# 0.0 1.0 zdhrhqmorn_3.png
# 1.0 0.0 hkbfkszcyr_4.png
# 0.0 1.0 fsywibkykv_1.png
# 0.0 1.0 gevbsktxjk_3.png
# 0.0 1.0 ajusgabgcr_4.png
# 1.0 0.0 zscrfkkjph_5.png
# 1.0 0.0 ahlilvgbjd_4.png
# 0.0 1.0 bpjwhlzkst_6.png
# 1.0 0.0 rnfbjblemd_4.png
# 0.0 1.0 epinsihsxf_1.png
# 1.0 0.0 rbufvipinj_5.png
# 0.0 1.0 cxvayntesu_2.png
# 0.0 1.0 oeqjhgzeai_2.png
# 1.0 0.0 fuixycdfqu_1.png
# 1.0 0.0 tukxjvjyxx_1.png
# 1.0 0.0 ugzrhiwigv_5.png
# 0.0 1.0 pehmdoijqb_7.png
# 1.0 0.0 upghghmmvt_6.png
# 0.0 1.0 eztwadaxde_2.png
# 1.0 0.0 hlhaljdyga_7.png
# 0.0 1.0 wwbbevqdac_3.png
# 1.0 0.0 wexrwnpacs_4.png
# 0.0 1.0 frzrswqycd_6.png
# 0.0 1.0 wdyzzjzfdl_7.png
# 0.0 1.0 cwthksdnco_5.png
# 1.0 0.0 elyosecnfp_7.png
# 1.0 0.0 ciqtrvvokw_7.png
# 1.0 0.0 yobixzolgw_4.png
# 0.0 1.0 tsgcssoqur_6.png
# 1.0 0.0 vlastaykkk_4.png
# 0.0 1.0 qyqufaskjs_5.png
# 1.0 0.0 jexttqprhw_1.png
# 0.0 1.0 kysghtqyes_3.png
# 0.0 1.0 nclgxngmcx_4.png
# 0.0 1.0 ypasdmkmuv_5.png
# 1.0 0.0 maxjdmaaax_7.png
# 1.0 0.0 pnuaczdxdj_4.png
# 1.0 0.0 wtxbmlzyff_2.png
# 0.0 1.0 uvzlfuxalu_7.png
# 0.0 1.0 uodarndzsb_1.png
# 1.0 0.0 xvykrmxyuk_6.png
# 1.0 0.0 ookwinesyd_1.png
# 0.0 1.0 wjuuqzqnbb_2.png
# 0.0 1.0 wsmuyaidpf_3.png
# 0.0 1.0 uhfmyeefsz_4.png
# 1.0 0.0 unlvgutmvv_7.png
# 0.0 1.0 kmqprpvlob_4.png
# 1.0 0.0 pmdrdiqsdt_7.png
# 1.0 0.0 zgwcwubyih_3.png
# 1.0 0.0 exqfnbnwll_5.png
# 0.0 1.0 mtvwmdmenk_3.png
# 0.0 1.0 xnlplanvyz_3.png
# 1.0 0.0 jjegzfkwua_1.png
# 1.0 0.0 fdppujxagz_5.png
# 1.0 0.0 uyjizmtxsr_3.png
# 0.0 1.0 ghpnfodcij_6.png
# 1.0 0.0 cpgayhckef_3.png
# 1.0 0.0 kkhkcdyuyu_5.png
# 1.0 0.0 dilfumvxqx_3.png
# 1.0 0.0 wswzulamik_5.png
# 1.0 0.0 cdtptxybyv_3.png
# 1.0 0.0 ylpmpzlxhc_2.png
# 1.0 0.0 ekqajwwwan_3.png
# 1.0 0.0 qjmmfjyorx_6.png
# 1.0 0.0 uxuetrjkvw_2.png
# 0.0 1.0 dnocqlgupe_7.png
# 1.0 0.0 yrtpcmtext_3.png
# 0.0 1.0 rhkxofkyja_4.png
# 0.0 1.0 yuzdamakoa_2.png
# 1.0 0.0 ehrrreprkw_6.png
# 1.0 0.0 rlanlrwraj_3.png
# 1.0 0.0 dreiuqfayx_6.png
# 1.0 0.0 opletbcjvs_7.png
# 0.0 1.0 vddzflpeat_5.png
# 0.0 1.0 cqkwtgecwf_5.png
# 0.0 1.0 ezolzuxyio_6.png
# 0.0 1.0 xylxjtdsdq_3.png
# 0.0 1.0 vftavpyqby_4.png
# 0.0 1.0 jorfxyiizk_3.png
# 0.0 1.0 oxsmxlvbzo_6.png
# 0.0 1.0 bfnossqoxp_3.png
# 0.0 1.0 xrxzalqmrz_7.png
# 0.0 1.0 wyrqxpzztf_3.png
# 0.0 1.0 fpqhqpiiqq_3.png
# 1.0 0.0 regiyqjuoh_3.png
# 0.0 1.0 lpwtacajzf_7.png
# 1.0 0.0 lcwpkxdevw_2.png
# 0.0 1.0 hkmznpevrk_3.png
# 0.0 1.0 oaubboazvv_1.png
# 1.0 0.0 wcuiivptnj_3.png
# 1.0 0.0 edvgsefgph_6.png
# 0.0 1.0 gofcvoyogl_7.png
# 1.0 0.0 kpnqwouwbq_6.png
# 1.0 0.0 kvdbhvdjib_5.png
# 0.0 1.0 cxwcpgspni_2.png
# 1.0 0.0 rujvrtqddt_4.png
# 0.0 1.0 vkvnatqfpn_3.png
# 1.0 0.0 zhinwryvae_6.png
# 1.0 0.0 xwroyfpdjz_7.png
# 0.0 1.0 omhzxmlgqd_5.png
# 0.0 1.0 juuxucpukk_7.png
# 0.0 1.0 frzefbsgmo_4.png
# 1.0 0.0 qojgeidoat_5.png
# 1.0 0.0 enybsjbxeu_1.png
# 0.0 1.0 bxgkydnxzv_1.png
# 0.0 1.0 bqtnaozkjr_7.png
# 1.0 0.0 nxnbsnvllf_6.png
# 0.0 1.0 ajiyrjfyzp_6.png
# 1.0 0.0 mxedmyiofh_6.png
# 0.0 1.0 xkfliqnmwt_2.png
# 0.0 1.0 crxnkfunvm_3.png
# 0.0 1.0 ffloxijuta_7.png
# 1.0 0.0 wexrwnpacs_7.png
# 1.0 0.0 acazlolrpz_3.png
# 1.0 0.0 kucidldvst_3.png
# 1.0 0.0 tjtmlczbqy_4.png
# 1.0 0.0 zuifqrgdqe_2.png
# 1.0 0.0 lcjqoxhdvs_3.png
# 0.0 1.0 rraluxdmqu_4.png
# 0.0 1.0 itnumzdchb_3.png
# 0.0 1.0 jegaokdbdb_1.png
# 1.0 0.0 xflhxvykmq_4.png
# 0.0 1.0 qhzszqjbky_2.png
# 1.0 0.0 ltrfgcytlz_6.png
# 0.0 1.0 fygxczhbsf_1.png
# 1.0 0.0 qlkuhkkpkx_6.png
# 0.0 1.0 yimsmlvjhk_6.png
# 0.0 1.0 wcqvzujamg_2.png

# %%
pred = net(img)
pred.shape

# %%
pred = torch.ceil(pred[0][0])
pred = pred.detach().numpy()
pred
